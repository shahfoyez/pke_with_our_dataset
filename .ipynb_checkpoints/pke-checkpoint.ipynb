# %%
import sys
sys.path.append('/PKEBenchmark')
import pke
# !pip install datasets
# !python -m spacy download en_core_web_sm
for path in sys.path:
    print(path)
print(pke.__file__)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in c:\users\ashraff\appdata\roaming\python\python39\site-packages (2.3.2)
# Requirement already satisfied: xxhash in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from datasets) (3.0.0)
# Requirement already satisfied: dill<0.3.6 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in c:\programdata\anaconda3\lib\site-packages (from datasets) (2022.2.0)
# Requirement already satisfied: requests>=2.19.0 in c:\programdata\anaconda3\lib\site-packages (from datasets) (2.27.1)
# Requirement already satisfied: pyarrow>=6.0.0 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from datasets) (8.0.0)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from datasets) (1.4.2)
# Requirement already satisfied: tqdm>=4.62.1 in c:\programdata\anaconda3\lib\site-packages (from datasets) (4.64.0)
# Requirement already satisfied: aiohttp in c:\programdata\anaconda3\lib\site-packages (from datasets) (3.8.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from datasets) (0.8.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from datasets) (21.3)
# Requirement already satisfied: responses<0.19 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from datasets) (0.18.0)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from datasets) (1.21.5)
# Requirement already satisfied: multiprocess in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from datasets) (0.70.13)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.6.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->datasets) (3.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (3.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (1.6.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (5.1.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from en-core-web-sm==3.4.1) (3.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.21.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.7)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.9.1)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.6.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (61.2.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.9.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (21.3)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.27.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ashraff\appdata\roaming\python\python39\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.8)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# C:\Users\Ashraff\PKE-OurDataset
# C:\ProgramData\Anaconda3\python39.zip
# C:\ProgramData\Anaconda3\DLLs
# C:\ProgramData\Anaconda3\lib
# C:\ProgramData\Anaconda3
#
# C:\Users\Ashraff\AppData\Roaming\Python\Python39\site-packages
# C:\ProgramData\Anaconda3\lib\site-packages
# C:\ProgramData\Anaconda3\lib\site-packages\win32
# C:\ProgramData\Anaconda3\lib\site-packages\win32\lib
# C:\ProgramData\Anaconda3\lib\site-packages\Pythonwin
# /PKEBenchmark
# C:\Users\Ashraff\PKE-OurDataset\pke\__init__.py

# %%
import spacy
from spacy.tokenizer import _get_regex_pattern

nlp = spacy.load("en_core_web_sm")

# Tokenization fix for in-word hyphens (e.g. 'non-linear' would be kept 
# as one token instead of default spacy behavior of 'non', '-', 'linear')
# https://spacy.io/usage/linguistic-features#native-tokenizer-additions

from spacy.lang.char_classes import ALPHA, ALPHA_LOWER, ALPHA_UPPER
from spacy.lang.char_classes import CONCAT_QUOTES, LIST_ELLIPSES, LIST_ICONS
from spacy.util import compile_infix_regex

# Modify tokenizer infix patterns
infixes = (
    LIST_ELLIPSES
    + LIST_ICONS
    + [
        r"(?<=[0-9])[+\-\*^](?=[0-9-])",
        r"(?<=[{al}{q}])\.(?=[{au}{q}])".format(
            al=ALPHA_LOWER, au=ALPHA_UPPER, q=CONCAT_QUOTES
        ),
        r"(?<=[{a}]),(?=[{a}])".format(a=ALPHA),
        # ✅ Commented out regex that splits on hyphens between letters:
        # r"(?<=[{a}])(?:{h})(?=[{a}])".format(a=ALPHA, h=HYPHENS),
        r"(?<=[{a}0-9])[:<>=/](?=[{a}])".format(a=ALPHA),
    ]
)

infix_re = compile_infix_regex(infixes)
nlp.tokenizer.infix_finditer = infix_re.finditer

# %%
from tqdm.notebook import tqdm
from datasets import load_dataset

# benchmark = "inspec"
# benchmark = "pake"
benchmark = "pakeNew"
# benchmark = "pake-m-2k"

# ayesha08/pake-m-2k


# dataset = load_dataset('ayesha08/'+benchmark)
dataset = load_dataset('foyez/'+benchmark)

# load the inspec dataset
# dataset = load_dataset("csv", data_files={'train': 'test.csv', 'test': 'test1.csv'}, column_names=["title", "abstract"])

# pre-process training and test splits
train = []
for sample in tqdm(dataset['train']):
    train.append(nlp(sample["title"]+". "+sample["abstract"]))
test = []
for sample in tqdm(dataset['test']):
    test.append(nlp(sample["title"]+". "+sample["abstract"]))
# Out:
# Using custom data configuration foyez--pake-cb168bd54547dfb3
# Reusing dataset csv (C:\Users\Ashraff\.cache\huggingface\datasets\foyez___csv\foyez--pake-cb168bd54547dfb3\0.0.0\51cce309a08df9c4d82ffd9363bbe090bf173197fc01a71b034e8594995a1a58)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
from pke import compute_document_frequency, compute_lda_model
from string import punctuation


# computing LDA and DF counts

compute_document_frequency(
    documents=train,
    output_file='data/{}.df.gz'.format(benchmark),
    language='en',              # language of the input files
    normalization='stemming',   # use porter stemmer
    stoplist=list(punctuation), # stoplist (punctuation marks)
    n=5                         # compute n-grams up to 5-grams
)

compute_lda_model(
    documents=train,
    output_file="data/{}.lda.pickle.gz".format(benchmark),
    n_topics=500,               # number of topics
    language='en',              # language of the input files
    stoplist=list(punctuation), # stoplist (punctuation marks)
    normalization='stemming'    # use porter stemmer
)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
from pke import load_document_frequency_file, load_lda_model

df = load_document_frequency_file(input_file='data/{}.df.gz'.format(benchmark))
lda_model = load_lda_model(input_file="data/{}.lda.pickle.gz".format(benchmark))

# %%
from pke.unsupervised import *

from timeit import default_timer as timer

outputs = {}
elapsed_times = {}
for model in [TfIdf, FirstPhrases, YAKE, PAKE]:
    outputs[model.__name__] = []
    
    extractor = model()
    start = timer()
    for i, doc in enumerate(tqdm(test)):
        extractor.load_document(input=doc, language='en')
        extractor.grammar_selection(grammar="NP: {<ADJ>*<NOUN|PROPN>+}")
        if model.__name__ in ["TfIdf"]:
            extractor.candidate_weighting(df=df)
        elif model.__name__ in ["TopicalPageRank"]:
            extractor.candidate_weighting(lda_model=lda_model)
        else:
            extractor.candidate_weighting()
        outputs[model.__name__].append([u for u,v in extractor.get_n_best(n=10, stemming=True)])
    end = timer()
    elapsed_times[model.__name__] = end - start
    #print("Elapsed time for {}: {:.2f}s - {:.2f} it/s".format(model.__name__, end - start,  len(test) / (end - start)))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# word*******************************
# advertisement
# tag*******************************
# NN
# word*******************************
# video
# tag*******************************
# NN
# word*******************************
# for
# tag*******************************
# IN
# word*******************************
# new
# tag*******************************
# JJ
# word*******************************
# game
# tag*******************************
# NN
# word*******************************
# ..
# tag*******************************
# NN
# word*******************************
# i
# tag*******************************
# NN
# word*******************************
# 'm
# tag*******************************
# VBP
# word*******************************
# looking
# tag*******************************
# VBG
# word*******************************
# someone
# tag*******************************
# NN
# word*******************************
# to
# tag*******************************
# TO
# word*******************************
# make
# tag*******************************
# VB
# word*******************************
# me
# tag*******************************
# PRP
# word*******************************
# an
# tag*******************************
# DT
# word*******************************
# animated
# tag*******************************
# VBN
# word*******************************
# a
# tag*******************************
# DT
# {'advertisement video': 0.0038307629019222753, 'new game': 0.005121375157251002, 'video': 0.07189903628427902, 'game': 0.022970051653299746, 'assets': 0.16294898831611185, 'animation': 0.10049949630442466, 'own voice': 2.000000000000001, 'characters': 0.06952418303973844, 'voice': 0.13904836607947688, 'screen': 0.16294898831611185, 'lot': 0.16294898831611185, 'action': 0.16294898831611185, 'more detail': 2.0000000000000004, 'children': 0.16294898831611185, 'project': 0.16294898831611185, 'demos': 0.22095449677911438, 'work': 0.14767993590430528, '3d animation': 1.9999999999999998, 'effects animation video production': 0.0001769661858141507, 'video services': 0.010968131166500831}
# BEST ASC*******************************************
# ['effects animation video production', 'advertisement video', 'new game', 'video services', 'game', 'characters', 'video', 'animation', 'voice', 'work', 'assets', 'screen', 'lot', 'action', 'children', 'project', 'demos', '3d animation', 'more detail', 'own voice']
# After checking Similarity**********************
# ['effects animation video production', 'advertisement video', 'new game', 'video services', 'characters', 'animation', 'voice', 'work', 'assets', 'screen', 'lot', 'action', 'children', 'project', 'demos', 'more detail']
# Top 10*****************************************
# ('effect anim video product', 0.0001769661858141507)
# ('advertis video', 0.0038307629019222753)
# ('new game', 0.005121375157251002)
# ('video servic', 0.010968131166500831)
# ('charact', 0.06952418303973844)
# ('anim', 0.10049949630442466)
# ('voic', 0.13904836607947688)
# ('work', 0.14767993590430528)
# ('asset', 0.16294898831611185)
# ('screen', 0.16294898831611185)
# ********************************************
# word*******************************
# short
# tag*******************************
# JJ
# word*******************************
# form
# tag*******************************
# NN
# word*******************************
# video
# tag*******************************
# NN
# word*******************************
# editor
# tag*******************************
# NN
# word*******************************
# (
# tag*******************************
# (
# word*******************************
# tiktok
# tag*******************************
# NN
# word*******************************
# /
# tag*******************************
# NN
# word*******************************
# ig
# tag*******************************
# NN
# word*******************************
# reels
# tag*******************************
# NNS
# word*******************************
# youtube
# tag*******************************
# NN
# word*******************************
# )
# tag*******************************
# )
# word*******************************
# ..
# tag*******************************
# NN
# word*******************************
# hey
# tag*******************************
# NN
# word*******************************
# !
# tag*******************************
# .
# word*******************************
# my
# tag*******************************
# PRP$
# word*******************************
# name
# tag*******************************
# NN
# word*******************************
# is
# tag*******************************
# VBZ
# word*******************************
# zach
# tag*******************************
# NN
# word*******************************
# and
# tag*******************************
# CC
# word*******************************
# i
# tag*******************************
# NN
# word*******************************
# am
# tag*******************************
# VBP
# word*******************************
# a
# tag*******************************
# DT
# word*******************************
# transformational
# tag*******************************
# JJ
# word*******************************
# life
# tag*******************************
# NN
# word*******************************
# coach
# tag*******************************
# NN
# word*******************************
#
#
# tag*******************************
# NN
# word*******************************
# content
# tag*******************************
# NN
# word*******************************
# creator
# tag*******************************
# NN
# word*******************************
# :
# tag*******************************
# :
# word*******************************
# @zachweiss
# tag*******************************
# NN
# word*******************************
# need
# tag*******************************
# NN
# word*******************************
# help
# tag*******************************
# NN
# word*******************************
# editing
# tag*******************************
# VBG
# word*******************************
# videos
# tag*******************************
# NNS
# word*******************************
# for
# tag*******************************
# IN
# word*******************************
# short-form
# tag*******************************
# NN
# word*******************************
# ,
# tag*******************************
# ,
# word*******************************
# shorts
# tag*******************************
# NNS
# word*******************************
# .
# tag*******************************
# .
# word*******************************
# as
# tag*******************************
# IN
# word*******************************
# trial
# tag*******************************
# NN
# word*******************************
# start
# tag*******************************
# NN
# word*******************************
# this
# DT
# word*******************************
# estimates
# tag*******************************
# NNS
# word*******************************
# now
# tag*******************************
# RB
# word*******************************
# let
# tag*******************************
# VB
# word*******************************
# 's
# tag*******************************
# POS
# word*******************************
# it
# tag*******************************
# PRP
# word*******************************
# 1
# tag*******************************
# CD
# word*******************************
# -
# tag*******************************
# :
# word*******************************
# 5
# tag*******************************
# CD
# word*******************************
# ta
# tag*******************************
# NN
# word*******************************
# ...
# tag*******************************
# :
# word*******************************
# production
# tag*******************************
# NN
# word*******************************
# services
# tag*******************************
# NNS
# word*******************************
# videography
# tag*******************************
# NN
# Weight*****************************************
# {'short form video editor': 1.943054629916761e-05, 'tiktok': 0.04885745894793966, 'ig reels': 1.0000000000000002, 'youtube': 0.09771491789587931, 'name': 199999983451.92715, 'zach': 0.16447741850459066, 'transformational life coach': 0.026696096390257353, 'content creator': 0.06743737221958199, 'help': 0.2513501319882206, 'videos': 0.09007833661377816, 'short-form': 0.2513501319882206, 'youtube shorts': 0.01633442260991043, 'trial start': 0.09591029309078895, 'project': 0.2915074828831309, 'hours': 0.2915074828831309, 'zoom calls': 0.09286824112350527, 'clients': 0.2915074828831309, 'micro-content': 0.2915074828831309, 'example': 0.31957691389990456, 'software': 0.31957691389990456, 'combination': 0.31957691389990456, 'fcpx': 0.2159245167726295, 'descript': 0.2159245167726295, 'things': 0.14655731595327942, 'continued basis': 0.1780781766444523, 'budget': 0.35706524915504073, 'pre-set retainer': 0.14612601496069097, 'x': 99999991725.96358, 'month': 0.37044029561019565, 'proposal': 0.38158079894806457, 'estimates': 0.38158079894806457, 'ta': 199999983451.92715, 'video editing video production video services videography': 4.336272950609164e-05}
# BEST ASC*******************************************
# ['short form video editor', 'video editing video production video services videography', 'youtube shorts', 'transformational life coach', 'tiktok', 'content creator', 'videos', 'zoom calls', 'trial start', 'youtube', 'pre-set retainer', 'things', 'zach', 'continued basis', 'fcpx', 'descript', 'help', 'short-form', 'project', 'hours', 'clients', 'micro-content', 'example', 'software', 'combination', 'budget', 'month', 'proposal', 'estimates', 'ig reels', 'x', 'name', 'ta']
# After checking Similarity**********************
# ['short form video editor', 'video editing video production video services videography', 'youtube shorts', 'transformational life coach', 'tiktok', 'content creator', 'videos', 'zoom calls', 'trial start', 'pre-set retainer', 'things', 'zach', 'continued basis', 'fcpx', 'descript', 'help', 'project', 'hours', 'clients', 'micro-content', 'example', 'software', 'combination', 'budget', 'month', 'proposal', 'estimates', 'ig reels', 'x', 'name', 'ta']
# Top 10*****************************************
# ('short form video editor', 1.943054629916761e-05)
# ('video edit video product video servic videographi', 4.336272950609164e-05)
# ('youtub short', 0.01633442260991043)
# ('transform life coach', 0.026696096390257353)
# ('tiktok', 0.04885745894793966)
# ('content creator', 0.06743737221958199)
# ('video', 0.09007833661377816)
# ('zoom call', 0.09286824112350527)
# ('trial start', 0.09591029309078895)
# ('pre-set retain', 0.14612601496069097)
# ********************************************
# word*******************************
# macroeconomics
# tag*******************************
# NNS
# word*******************************
# expert
# tag*******************************
# NN
# word*******************************
# -
# tag*******************************
# :
# word*******************************
# technical
# tag*******************************
# JJ
# word*******************************
# person
# tag*******************************
# NN
# word*******************************
# ..
# tag*******************************
# NN
# word*******************************
# looking
# tag*******************************
# VBG
# word*******************************
# for
# tag*******************************
# IN
# word*******************************
# qualified
# tag*******************************
# VBN
# word*******************************
# and
# tag*******************************
# CC
# word*******************************
# experienced
# tag*******************************
# JJ
# word*******************************
# macro
# tag*******************************
# NN
# word*******************************
# economics
# tag*******************************
# NNS
# word*******************************
#
#
# tag*******************************
# NN
# word*******************************
# who
# tag*******************************
# WP
# word*******************************
# can
# tag*******************************
# MD
# word*******************************
# do
# tag*******************************
# VB
# word*******************************
# me
# tag*******************************
# PRP
# word*******************************
# one
# tag*******************************
# CD
# word*******************************
# thing
# tag*******************************
# NN
# word*******************************
# thanks
# tag*******************************
# NNS
# word*******************************
# econometrics
# tag*******************************
# NNS
# word*******************************
# finance
# tag*******************************
# NN
# word*******************************
# statistical
# tag*******************************
# JJ
# word*******************************
# analysis
# tag*******************************
# NN
# word*******************************
# statistics
# tag*******************************
# NNS
# word*******************************
# $
# tag*******************************
# $
# word*******************************
# 27
# tag*******************************
# CD
# word*******************************
# /
# tag*******************************
# NN
# word*******************************
# hr
# tag*******************************
# NN
# word*******************************
# (
# tag*******************************
# (
# word*******************************
# avg
# tag*******************************
# NN
# word*******************************
# bid
# tag*******************************
# NN
# word*******************************
# )
# tag*******************************
# )
# Weight*****************************************
# {'macroeconomics expert': 0.0019843530285746074, 'technical person': 0.001786573863220955, 'experienced macro economics expert': 3.790241609712643e-05, 'technical thing thanks econometrics economics finance': 7.852964118363392e-07, 'statistical analysis statistics': 0.0009821125276567647, 'hr': 199999983451.92715, 'avg bid': 0.008827603756537496}
# BEST ASC*******************************************
# ['technical thing thanks econometrics economics finance', 'experienced macro economics expert', 'statistical analysis statistics', 'technical person', 'macroeconomics expert', 'avg bid', 'hr']
# After checking Similarity**********************
# ['technical thing thanks econometrics economics finance', 'experienced macro economics expert', 'statistical analysis statistics', 'technical person', 'macroeconomics expert', 'avg bid', 'hr']
# Top 10*****************************************
# ('technic thing thank econometr econom financ', 7.852964118363392e-07)
# ('experienc macro econom expert', 3.790241609712643e-05)
# ('statist analysi statist', 0.0009821125276567647)
# ('technic person', 0.001786573863220955)
# ('macroeconom expert', 0.0019843530285746074)
# ('avg bid', 0.008827603756537496)
# ('hr', 199999983451.92715)
# ********************************************
# word*******************************
# crm
# tag*******************************
# NN
# word*******************************
# followup
# tag*******************************
# NN
# word*******************************
# manager
# tag*******************************
# NN
# word*******************************
# needed
# tag*******************************
# VBN
# word*******************************
# ..
# tag*******************************
# NN
# word*******************************
# hi
# tag*******************************
# NN
# word*******************************
# ,
# tag*******************************
# ,
# word*******************************
# i
# tag*******************************
# NN
# word*******************************
# need
# tag*******************************
# NN
# word*******************************
# a
# tag*******************************
# DT
# word*******************************
# tester
# tag*******************************
# NN
# word*******************************
# for
# tag*******************************
# IN
# word*******************************
# chrcking
# tag*******************************
# VBG
# word*******************************
# and
# tag*******************************
# CC
# word*******************************
# managing
# tag*******************************
# VBG
# word*******************************
# the
# tag*******************************
# DT
# word*******************************
# named
# tag*******************************
# VBN
# word*******************************
#
#
# tag*******************************
# NN
# word*******************************
# will
# tag*******************************
# MD
# word*******************************
# hire
# tag*******************************
# NN
# word*******************************
# best
# tag*******************************
# JJS
# word*******************************
# talent
# tag*******************************
# NN
# word*******************************
# only
# tag*******************************
# RB
# word*******************************
# thank
# tag*******************************
# NN
# word*******************************
# you
# tag*******************************
# PRP
# word*******************************
# php
# tag*******************************
# NN
# word*******************************
# software
# tag*******************************
# NN
# word*******************************
# testing
# tag*******************************
# VBG
# word*******************************
# /
# tag*******************************
# NN
# word*******************************
# qa
# tag*******************************
# NN
# word*******************************
# usability
# tag*******************************
# NN
# Weight*****************************************
# {'crm followup manager': 0.00018615544186424278, 'tester': 0.14875792488674186, 'crm': 0.050613976818299405, 'followup': 0.07604054424650378, 'best talent': 0.04235649978035029, 'crm php software testing': 5.473937383066138e-05, 'testing': 0.09927296164532458, 'qa usability testing': 0.1324307423862379}
# BEST ASC*******************************************
# ['crm php software testing', 'crm followup manager', 'best talent', 'crm', 'followup', 'testing', 'qa usability testing', 'tester']
# After checking Similarity**********************
# ['crm php software testing', 'crm followup manager', 'best talent', 'crm', 'followup', 'testing', 'qa usability testing', 'tester']
# Top 10*****************************************
# ('crm php softwar test', 5.473937383066138e-05)
# ('crm followup manag', 0.00018615544186424278)
# ('best talent', 0.04235649978035029)
# ('crm', 0.050613976818299405)
# ('followup', 0.07604054424650378)
# ('test', 0.09927296164532458)
# ('qa usabl test', 0.1324307423862379)
# ('tester', 0.14875792488674186)
# ********************************************
# word*******************************
# freelancer
# tag*******************************
# NN
# word*******************************
# wanted
# tag*******************************
# VBD
# word*******************************
# to
# tag*******************************
# TO
# word*******************************
# work
# tag*******************************
# NN
# word*******************************
# in
# tag*******************************
# IN
# word*******************************
# architectural
# tag*******************************
# JJ
# word*******************************
# and
# tag*******************************
# CC
# word*******************************
# interior
# tag*******************************
# NN
# word*******************************
# design
# tag*******************************
# NN
# word*******************************
# ..
# tag*******************************
# NN
# word*******************************
#
# tag*******************************
# NN
# word*******************************
# please
# tag*******************************
# NN
# word*******************************
# read
# tag*******************************
# NN
# word*******************************
# the
# tag*******************************
# DT
# word*******************************
# details
# tag*******************************
# NNS
# word*******************************
# carefully
# tag*******************************
# RB
# word*******************************
# ,
# tag*******************************
# ,
# word*******************************
# we
# tag*******************************
# PRP
# word*******************************
# would
# tag*******************************
# MD
# word*******************************
# like
# tag*******************************
# IN
# word*******************************
# agree
# tag*******************************
# NN
# word*******************************
# with
# tag*******************************
# IN
# word*******************************
#
#
# tag*******************************
# NN
# word*******************************
# freelancers
# tag*******************************
# NNS
# word*******************************
# on
# tag*******************************
# IN
# word*******************************
# projects
# tag*******************************
# NNS
# word*******************************
# employment
# tag*******************************
# NN
# word*******************************
# system
# tag*******************************
# NN
# word*******************************
# for
# tag*******************************
# IN
# word*******************************
# a
# tag*******************************
# DT
# word*******************************
# number
# tag*******************************
# NN
# word*******************************
# of
# tag*******************************
# IN
# word*******************************
# hours
# tag*******************************
# NNS
# word*******************************
# be
# tag*******************************
# VB
# word*******************************
# agreed
# tag*******************************
# VBD
# word*******************************
# upon
# tag*******************************
# IN
# {'freelancer': 0.14789765552716508, 'freelancers': 0.11829195176934561, 'interior design': 0.016883893681656433, 'details': 0.06126940481459608, 'projects': 0.06126940481459608, 'employment system': 0.0037680851317073174, 'number': 0.06126940481459608, 'hours': 0.10091861410212462, 'business': 0.18479232002662416, 'idea': 0.18479232002662416, 'contract': 0.08018581551188451, 'terms': 0.2482672369548959, 'conditions': 0.2482672369548959, 'value': 0.2482672369548959, 'hire': 0.16315167948297568, 'freelancer website': 0.03811775545853181, 'work': 0.17706718159787016, 'saturday': 0.21429045302148522, 'thursday': 0.21429045302148522, 'rate': 0.3160104237938089, 'day': 0.3160104237938089, 'dates': 0.3160104237938089, 'periods': 0.3160104237938089, 'period': 0.2732320277997463, 'first period': 2.0000000000000004, 'am': 199999983451.92715, 'pm': 66666661150.64239, 'emirates time': 0.07263683960430611, 'personal interview': 0.15907770917654818, 'cvs': 0.2438543799555962, 'good portfolio': 0.19180000059644117, 'zoom': 0.2438543799555962, 'application': 0.35329761967470663, 'success': 0.36661201126684834, 'interview': 0.30129523476119735, 'fre': 0.36661201126684834, '3ds max autocad building architecture': 0.007401537403518686, 'interior design landscape design': 0.0017215561324485193}
# BEST ASC*******************************************
# ['interior design landscape design', 'employment system', '3ds max autocad building architecture', 'interior design', 'freelancer website', 'details', 'projects', 'number', 'emirates time', 'contract', 'hours', 'freelancers', 'freelancer', 'personal interview', 'hire', 'work', 'business', 'idea', 'good portfolio', 'saturday', 'thursday', 'cvs', 'zoom', 'terms', 'conditions', 'value', 'period', 'interview', 'rate', 'day', 'dates', 'periods', 'application', 'success', 'fre', 'first period', 'pm', 'am']
# After checking Similarity**********************
# ['interior design landscape design', 'employment system', '3ds max autocad building architecture', 'freelancer website', 'details', 'projects', 'number', 'emirates time', 'contract', 'hours', 'freelancers', 'personal interview', 'hire', 'work', 'business', 'idea', 'good portfolio', 'saturday', 'thursday', 'cvs', 'zoom', 'terms', 'conditions', 'value', 'period', 'rate', 'day', 'dates', 'periods', 'application', 'success', 'fre', 'pm', 'am']
# Top 10*****************************************
# ('interior design landscap design', 0.0017215561324485193)
# ('employ system', 0.0037680851317073174)
# ('3d max autocad build architectur', 0.007401537403518686)
# ('freelanc websit', 0.03811775545853181)
# ('detail', 0.06126940481459608)
# ('project', 0.06126940481459608)
# ('number', 0.06126940481459608)
# ('emir time', 0.07263683960430611)
# ('contract', 0.08018581551188451)
# ('hour', 0.10091861410212462)
# ********************************************

# %%
from nltk.stem.snowball import SnowballStemmer as Stemmer
import numpy as np
    
# populates the references list with stemmed keyphrases
references = []

for sample in tqdm(dataset['test']):
    sample_keyphrases = []
    for keyphrase in sample["keyphrases"].split(','):
        keyphrase = keyphrase.strip()
        print("*************************Keyphrase*************************")
        print(keyphrase)
    
        # tokenize keyphrase
        tokens = [token.text for token in nlp(keyphrase)]
        
        # normalize tokens using Porter's stemming
        stems = [Stemmer('porter').stem(tok.lower()) for tok in tokens]
        print("*************************Stemed*************************")
        print(stems)
        sample_keyphrases.append(" ".join(stems))
       
    print("*************************sample_keyphrases*************************")
    references.append(sample_keyphrases)
    print(sample_keyphrases)

def evaluate(top_N_keyphrases, references, cutoff=5):
    P = len(set(top_N_keyphrases[:cutoff]) & set(references)) / len(top_N_keyphrases[:cutoff])
    R = len(set(top_N_keyphrases[:cutoff]) & set(references)) / len(references)
    F = (2*P*R)/(P+R) if (P+R) > 0 else 0 
    return (P, R, F)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# *************************Keyphrase*************************
# effects animation video production
# *************************Stemed*************************
# ['effect', 'anim', 'video', 'product']
# *************************Keyphrase*************************
# advertisement video
# *************************Stemed*************************
# ['advertis', 'video']
# *************************Keyphrase*************************
# new game
# *************************Stemed*************************
# ['new', 'game']
# *************************Keyphrase*************************
# video services
# *************************Stemed*************************
# ['video', 'servic']
# *************************Keyphrase*************************
# characters
# *************************Stemed*************************
# ['charact']
# *************************Keyphrase*************************
# animation
# *************************Stemed*************************
# ['anim']
# *************************Keyphrase*************************
# voice
# *************************Stemed*************************
# ['voic']
# *************************Keyphrase*************************
# work
# *************************Stemed*************************
# ['work']
# *************************Keyphrase*************************
# assets
# *************************Stemed*************************
# ['asset']
# *************************Keyphrase*************************
# screen
# *************************Stemed*************************
# ['screen']
# *************************Keyphrase*************************
# lot
# *************************Stemed*************************
# ['lot']
# *************************sample_keyphrases*************************
# ['effect anim video product', 'advertis video', 'new game', 'video servic', 'charact', 'anim', 'voic', 'work', 'asset', 'screen', 'lot']
# *************************Keyphrase*************************
# short form video editor
# *************************Stemed*************************
# ['short', 'form', 'video', 'editor']
# *************************Keyphrase*************************
# video editing video production video services videography
# *************************Stemed*************************
# ['video', 'edit', 'video', 'product', 'video', 'servic', 'videographi']
# *************************Keyphrase*************************
# youtube shorts
# *************************Stemed*************************
# ['youtub', 'short']
# *************************Keyphrase*************************
# transformational life coach
# *************************Stemed*************************
# ['transform', 'life', 'coach']
# *************************Keyphrase*************************
# tiktok
# *************************Stemed*************************
# ['tiktok']
# *************************Keyphrase*************************
# content creator
# *************************Stemed*************************
# ['content', 'creator']
# *************************Keyphrase*************************
# videos
# *************************Stemed*************************
# ['video']
# *************************Keyphrase*************************
# zoom calls
# *************************Stemed*************************
# ['zoom', 'call']
# *************************Keyphrase*************************
# trial start
# *************************Stemed*************************
# ['trial', 'start']
# *************************sample_keyphrases*************************
# ['short form video editor', 'video edit video product video servic videographi', 'youtub short', 'transform life coach', 'tiktok', 'content creator', 'video', 'zoom call', 'trial start']
# *************************Keyphrase*************************
# technical thing thanks econometrics economics finance
# *************************Stemed*************************
# ['technic', 'thing', 'thank', 'econometr', 'econom', 'financ']
# *************************Keyphrase*************************
# experienced macro economics expert
# *************************Stemed*************************
# ['experienc', 'macro', 'econom', 'expert']
# *************************Keyphrase*************************
# statistical analysis statistics
# *************************Stemed*************************
# ['statist', 'analysi', 'statist']
# *************************Keyphrase*************************
# technical person
# *************************Stemed*************************
# ['technic', 'person']
# *************************Keyphrase*************************
# macroeconomics expert
# *************************Stemed*************************
# ['macroeconom', 'expert']
# *************************sample_keyphrases*************************
# ['technic thing thank econometr econom financ', 'experienc macro econom expert', 'statist analysi statist', 'technic person', 'macroeconom expert']
# *************************Keyphrase*************************
# crm php software testing
# *************************Stemed*************************
# ['crm', 'php', 'softwar', 'test']
# *************************Keyphrase*************************
# crm followup manager
# *************************Stemed*************************
# ['crm', 'followup', 'manag']
# *************************Keyphrase*************************
# best talent
# *************************Stemed*************************
# ['best', 'talent']
# *************************Keyphrase*************************
# crm
# *************************Stemed*************************
# ['crm']
# *************************Keyphrase*************************
# followup
# *************************Stemed*************************
# ['followup']
# *************************Keyphrase*************************
# testing
# *************************Stemed*************************
# ['test']
# *************************Keyphrase*************************
# qa usability testing
# *************************Stemed*************************
# ['qa', 'usabl', 'test']
# *************************Keyphrase*************************
# tester
# *************************Stemed*************************
# ['tester']
# *************************sample_keyphrases*************************
# ['crm php softwar test', 'crm followup manag', 'best talent', 'crm', 'followup', 'test', 'qa usabl test', 'tester']
# *************************Keyphrase*************************
# interior design landscape design
# *************************Stemed*************************
# ['interior', 'design', 'landscap', 'design']
# *************************Keyphrase*************************
# employment system
# *************************Stemed*************************
# ['employ', 'system']
# *************************Keyphrase*************************
# 3ds max autocad building architecture
# *************************Stemed*************************
# ['3d', 'max', 'autocad', 'build', 'architectur']
# *************************Keyphrase*************************
# freelancer website
# *************************Stemed*************************
# ['freelanc', 'websit']
# *************************Keyphrase*************************
# details
# *************************Stemed*************************
# ['detail']
# *************************Keyphrase*************************
# projects
# *************************Stemed*************************
# ['project']
# *************************Keyphrase*************************
# number
# *************************Stemed*************************
# ['number']
# *************************Keyphrase*************************
# emirates time
# *************************Stemed*************************
# ['emir', 'time']
# *************************sample_keyphrases*************************
# ['interior design landscap design', 'employ system', '3d max autocad build architectur', 'freelanc websit', 'detail', 'project', 'number', 'emir time']

# %%
print("## Benchmarking on {}".format(benchmark))
print("| Model | it/s |  F@5 | F@10 |")
print("| :---- | ----:| ---: | ---: |")

# loop through the models
for model in outputs:
    
    f_scores = []
    # compute the P, R, F scores for the model
    for cutoff in [5, 10]:
        scores = []
        for i, output in enumerate(outputs[model]):
            scores.append(evaluate(output, references[i], cutoff))

        # compute the average scores
        P, R, F = np.mean(scores, axis=0)
        f_scores.append(F)
        
    print("| {}  | {:.1f} | {:.2f} | {:.2f} |".format(model,  len(test)/ elapsed_times[model], f_scores[0]*100, f_scores[1]*100))


        # print out the performance of the model
        #print("{} at {} P: {:.3f} R: {:.3f} F: {:.3f}".format(model, cutoff, avg_scores[0], avg_scores[1], avg_scores[2]))
# Out:
# ## Benchmarking on pake
# | Model | it/s |  F@5 | F@10 |
# | :---- | ----:| ---: | ---: |
# | TfIdf  | 135.6 | 51.10 | 67.31 |
# | FirstPhrases  | 160.7 | 57.83 | 69.42 |
# | YAKE  | 57.3 | 66.04 | 75.76 |
# | PAKE  | 8.8 | 77.55 | 92.44 |

# %%
import matplotlib.pyplot as plt
import numpy as np
model_name = np.array([]) 
f_5 = np.array([]) 
f_10 = np.array([])
# loop through the models
for model in outputs:
    
    f_scores = []
    # compute the P, R, F scores for the model
    for cutoff in [5, 10]:
        scores = []
        for i, output in enumerate(outputs[model]):
            scores.append(evaluate(output, references[i], cutoff))

        # compute the average scores
        P, R, F = np.mean(scores, axis=0)
        f_scores.append(F)
        
    model_name = np.append(model_name, model) 
    f_5 = np.append(f_5, f_scores[0]*100) 
    f_10 = np.append(f_10, f_scores[1]*100) 

plt.bar(model_name, f_5)
plt.show()
print("F@5")
plt.bar(model_name, f_10)
plt.show()
print("F@10")
# Out:
# F@5
# F@10
